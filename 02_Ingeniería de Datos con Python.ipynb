# %% [markdown]
# # Ingeniería de Datos en Python

# %% [markdown]
# ## Laboratorio 2

# %% [markdown]
# Objetivos Especificos:
#
# - Conectarse a las diversas Bases de Datos (BD).
# - Extraer informacion de una BD.
# - Enviar los datos extraídos a otra BD.

# %% [markdown]
# A continuación, la conexión a SQL Server.

# %%
import pyodbc as po
import pandas as pd

sql_credenciales = (
    'DRIVER={ODBC Driver 17 for SQL Server};'
    'SERVER=OMARJCM\SQLSERVER20219;'
    'DATABASE=NORTHWND;'
    'UID=sa;'
    'PWD=inexcelsisdeo;'
)

sql_conexion = po.connect( sql_credenciales )
sql_cursor = sql_conexion.cursor()

# %%
sql = """
    SELECT ord.OrderID, cu.CustomerID, cu.CompanyName, ROUND( SUM( od.Quantity * (od.UnitPrice * (1 - od.Discount)) ), 2) valor_total
    FROM Orders ord INNER JOIN [Order Details] od ON (ord.OrderID = od.OrderID)
            INNER JOIN Customers cu ON (ord.CustomerID = cu.CustomerID)
    GROUP BY ord.OrderID, cu.CustomerID, cu.CompanyName
    ORDER BY valor_total DESC, cu.CustomerID
"""

sql_df = pd.read_sql(sql, sql_conexion)
print(sql_df)
# Out:
#      OrderID CustomerID                 CompanyName  valor_total
# 0      10865      QUICK                  QUICK-Stop     16387.50
# 1      10981      HANAR               Hanari Carnes     15810.00
# 2      11030      SAVEA          Save-a-lot Markets     12615.05
# 3      10889      RATTC  Rattlesnake Canyon Grocery     11380.00
# 4      10417      SIMOB               Simons bistro     11188.40
# ..       ...        ...                         ...          ...
# 825    10898      OCEAN      Océano Atlántico Ltda.        30.00
# 826    10767      SUPRD            Suprêmes délices        28.00
# 827    10586      REGGC          Reggiani Caseifici        23.80
# 828    10807      FRANS              Franchi S.p.A.        18.40
# 829    10782      CACTU  Cactus Comidas para llevar        12.50
#
# [830 rows x 4 columns]

# %%
sql_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 830 entries, 0 to 829
# Data columns (total 4 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   OrderID      830 non-null    int64
#  1   CustomerID   830 non-null    object
#  2   CompanyName  830 non-null    object
#  3   valor_total  830 non-null    float64
# dtypes: float64(1), int64(1), object(2)
# memory usage: 26.1+ KB

# %% [markdown]
# A continuación, se presenta la conexión a PostgreSQL.

# %%
import psycopg2 as ps

pg_credenciales = {
    'dbname':'northwind',
    'user':'postgres',
    'password':'inexcelsisdeo',
    'host':'localhost',
    'port':5432
}

pg_conexion = ps.connect( **pg_credenciales )
pg_cursor = pg_conexion.cursor()

# %% [markdown]
# Se crea una base de datos Northwind en PostresSQL y luego también se crea la siguiente tabla:
#
# ~~~~sql
# CREATE TABLE IF NOT EXISTS public.facturado_clientes
# (
#     "OrderID" integer NOT NULL,
#     "CustomerID" character varying(200) COLLATE pg_catalog."default" NOT NULL,
#     "CompanyName" character varying(200) COLLATE pg_catalog."default",
#     valor_total double precision,
#     CONSTRAINT facturado_clientes_pkey PRIMARY KEY ("CustomerID", "OrderID")
# )
# ~~~~

# %%
tuplas = [ tuple(x) for x in sql_df.to_numpy() ]

sql = """
INSERT INTO facturado_clientes ("OrderID", "CustomerID", "CompanyName", "valor_total") VALUES (%s, %s, %s, %s);
"""

pg_cursor.executemany(sql, tuplas)
pg_conexion.commit()

# %%
sql = """
    SELECT *
    FROM facturado_clientes
"""
pg_cursor.execute( sql )

for registro in pg_cursor:
    print( registro )
# Out:
# (10865, 'QUICK', 'QUICK-Stop', 16387.5)
# (10981, 'HANAR', 'Hanari Carnes', 15810.0)
# (11030, 'SAVEA', 'Save-a-lot Markets', 12615.05)
# (10889, 'RATTC', 'Rattlesnake Canyon Grocery', 11380.0)
# (10417, 'SIMOB', 'Simons bistro', 11188.4)
# (10817, 'KOENE', 'Königlich Essen', 10952.84)
# (10897, 'HUNGO', 'Hungry Owl All-Night Grocers', 10835.24)
# (10479, 'RATTC', 'Rattlesnake Canyon Grocery', 10495.6)
# (10540, 'QUICK', 'QUICK-Stop', 10191.7)
# (10691, 'QUICK', 'QUICK-Stop', 10164.8)
# (10515, 'QUICK', 'QUICK-Stop', 9921.3)
# (10372, 'QUEEN', 'Queen Cozinha', 9210.9)
# (10424, 'MEREP', 'Mère Paillarde', 9194.56)
# (11032, 'WHITC', 'White Clover Markets', 8902.5)
# (10514, 'ERNSH', 'Ernst Handel', 8623.45)
# (10353, 'PICCO', 'Piccolo und mehr', 8593.28)
# (10816, 'GREAL', 'Great Lakes Food Market', 8446.45)
# (10360, 'BLONP', 'Blondesddsl père et fils', 7390.2)
# (11017, 'ERNSH', 'Ernst Handel', 6750.0)
# (10776, 'ERNSH', 'Ernst Handel', 6635.27)
# (10607, 'SAVEA', 'Save-a-lot Markets', 6475.4)
# (10895, 'ERNSH', 'Ernst Handel', 6379.4)
# (10612, 'SAVEA', 'Save-a-lot Markets', 6375.0)
# (11021, 'QUICK', 'QUICK-Stop', 6306.24)
# (10912, 'HUNGO', 'Hungry Owl All-Night Grocers', 6200.55)
# (10633, 'ERNSH', 'Ernst Handel', 5510.59)
# (10893, 'KOENE', 'Königlich Essen', 5502.11)
# (10351, 'ERNSH', 'Ernst Handel', 5398.72)
# (10324, 'SAVEA', 'Save-a-lot Markets', 5275.71)
# (10678, 'SAVEA', 'Save-a-lot Markets', 5256.5)
# (11072, 'ERNSH', 'Ernst Handel', 5218.0)
# (10634, 'FOLIG', 'Folies gourmandes', 4985.5)
# (10687, 'HUNGO', 'Hungry Owl All-Night Grocers', 4960.9)
# (10847, 'SAVEA', 'Save-a-lot Markets', 4931.92)
# (10440, 'SAVEA', 'Save-a-lot Markets', 4924.14)
# (10430, 'ERNSH', 'Ernst Handel', 4899.2)
# (10993, 'FOLKO', 'Folk och fä HB', 4895.44)
# (10694, 'QUICK', 'QUICK-Stop', 4825.0)
# (10979, 'ERNSH', 'Ernst Handel', 4813.5)
# (10616, 'GREAL', 'Great Lakes Food Market', 4807.0)
# (10595, 'ERNSH', 'Ernst Handel', 4725.0)
# (10510, 'SAVEA', 'Save-a-lot Markets', 4707.54)
# (10836, 'ERNSH', 'Ernst Handel', 4705.5)
# (11008, 'ERNSH', 'Ernst Handel', 4680.9)
# (10666, 'RICSU', 'Richter Supermarkt', 4666.94)
# (10841, 'SUPRD', 'Suprêmes délices', 4581.0)
# (10329, 'SPLIR', 'Split Rail Beer & Ale', 4578.43)
# (10745, 'QUICK', 'QUICK-Stop', 4529.8)
# (10658, 'QUICK', 'QUICK-Stop', 4464.6)
# (10711, 'SAVEA', 'Save-a-lot Markets', 4451.7)
# (10953, 'AROUT', 'Around the Horn', 4441.25)
# (10949, 'BOTTM', 'Bottom-Dollar Markets', 4422.0)
# (10657, 'SAVEA', 'Save-a-lot Markets', 4371.6)
# (10762, 'FOLKO', 'Folk och fä HB', 4337.0)
# (11064, 'SAVEA', 'Save-a-lot Markets', 4330.4)
# (10990, 'ERNSH', 'Ernst Handel', 4288.85)
# (10530, 'PICCO', 'Piccolo und mehr', 4180.0)
# (10518, 'TORTU', 'Tortuga Restaurante', 4150.05)
# (10605, 'MEREP', 'Mère Paillarde', 4109.7)
# (10941, 'SAVEA', 'Save-a-lot Markets', 4011.75)
# (10458, 'SUPRD', 'Suprêmes délices', 3891.0)
# (10401, 'RATTC', 'Rattlesnake Canyon Grocery', 3868.6)
# (10451, 'QUICK', 'QUICK-Stop', 3849.66)
# (10672, 'BERGS', 'Berglunds snabbköp', 3815.25)
# (10845, 'QUICK', 'QUICK-Stop', 3812.7)
# (10305, 'OLDWO', 'Old World Delicatessen', 3741.3)
# (11056, 'EASTC', 'Eastern Connection', 3740.0)
# (10789, 'FOLIG', 'Folies gourmandes', 3687.0)
# (10772, 'LEHMS', 'Lehmanns Marktstand', 3603.22)
# (10252, 'SUPRD', 'Suprêmes délices', 3597.9)
# (10962, 'QUICK', 'QUICK-Stop', 3584.0)
# (10988, 'RATTC', 'Rattlesnake Canyon Grocery', 3574.8)
# (10549, 'QUICK', 'QUICK-Stop', 3554.28)
# (10267, 'FRANK', 'Frankenversand', 3536.6)
# (10861, 'WHITC', 'White Clover Markets', 3523.4)
# (10359, 'SEVES', 'Seven Seas Imports', 3471.68)
# (10718, 'KOENE', 'Königlich Essen', 3463.0)
# (10698, 'ERNSH', 'Ernst Handel', 3436.44)
# (10709, 'GOURL', 'Gourmet Lanchonetes', 3424.0)
# (10339, 'MEREP', 'Mère Paillarde', 3354.0)
# (11033, 'RICSU', 'Richter Supermarkt', 3232.8)
# (10524, 'BERGS', 'Berglunds snabbköp', 3192.65)
# (10490, 'HILAA', 'HILARION-Abastos', 3163.2)
# (10688, 'VAFFE', 'Vaffeljernet', 3160.6)
# (10886, 'HANAR', 'Hanari Carnes', 3127.5)
# (10588, 'QUICK', 'QUICK-Stop', 3120.0)
# (10742, 'BOTTM', 'Bottom-Dollar Markets', 3118.0)
# (11039, 'LINOD', 'LINO-Delicateses', 3090.0)
# (10757, 'SAVEA', 'Save-a-lot Markets', 3082.0)
# (10400, 'EASTC', 'Eastern Connection', 3063.0)
# (11053, 'PICCO', 'Piccolo und mehr', 3055.0)
# (10801, 'BOLID', 'Bólido Comidas preparadas', 3026.85)
# (10286, 'QUICK', 'QUICK-Stop', 3016.0)
# (10852, 'RATTC', 'Rattlesnake Canyon Grocery', 2984.0)
# (10854, 'ERNSH', 'Ernst Handel', 2966.5)
# (10555, 'SAVEA', 'Save-a-lot Markets', 2944.4)
# (10802, 'SIMOB', 'Simons bistro', 2942.81)
# (10345, 'QUICK', 'QUICK-Stop', 2924.8)
# (10760, 'MAISD', 'Maison Dewey', 2917.0)
# (10382, 'ERNSH', 'Ernst Handel', 2900.0)
# (10701, 'HUNGO', 'Hungry Owl All-Night Grocers', 2864.5)
# (10561, 'FOLKO', 'Folk och fä HB', 2844.5)
# (10316, 'RATTC', 'Rattlesnake Canyon Grocery', 2835.0)
# (10713, 'SAVEA', 'Save-a-lot Markets', 2827.9)
# (10823, 'LILAS', 'LILA-Supermercado', 2826.0)
# (11012, 'FRANK', 'Frankenversand', 2825.3)
# (10546, 'VICTE', 'Victuailles en stock', 2812.0)
# (10629, 'GODOS', 'Godos Cocina Típica', 2775.05)
# (10805, 'THEBI', 'The Big Cheese', 2775.0)
# (10987, 'EASTC', 'Eastern Connection', 2772.0)
# (11001, 'FOLKO', 'Folk och fä HB', 2769.0)
# (10637, 'QUEEN', 'Queen Cozinha', 2761.94)
# (10894, 'SAVEA', 'Save-a-lot Markets', 2753.1)
# (10938, 'QUICK', 'QUICK-Stop', 2731.88)
# (10638, 'LINOD', 'LINO-Delicateses', 2720.05)
# (10402, 'ERNSH', 'Ernst Handel', 2713.5)
# (10302, 'SUPRD', 'Suprêmes délices', 2708.8)
# (10618, 'MEREP', 'Mère Paillarde', 2697.5)
# (10831, 'SANTG', 'Santé Gourmet', 2684.4)
# (10455, 'WARTH', 'Wartian Herkku', 2684.0)
# (10298, 'HUNGO', 'Hungry Owl All-Night Grocers', 2645.0)
# (11007, 'PRINI', 'Princesa Isabel Vinhos', 2633.9)
# (10787, 'LAMAI', "La maison d'Asie", 2622.76)
# (10851, 'RICAR', 'Ricardo Adocicados', 2603.0)
# (10393, 'SAVEA', 'Save-a-lot Markets', 2556.95)
# (10511, 'BONAP', "Bon app'", 2550.0)
# (10703, 'FOLKO', 'Folk och fä HB', 2545.0)
# (10567, 'HUNGO', 'Hungry Owl All-Night Grocers', 2519.0)
# (10465, 'VAFFE', 'Vaffeljernet', 2518.0)
# (10398, 'SAVEA', 'Save-a-lot Markets', 2505.6)
# (10255, 'RICSU', 'Richter Supermarkt', 2490.5)
# (10337, 'FRANK', 'Frankenversand', 2467.0)
# (10570, 'MEREP', 'Mère Paillarde', 2465.25)
# (10523, 'SEVES', 'Seven Seas Imports', 2444.31)
# (10340, 'BONAP', "Bon app'", 2436.18)
# (11031, 'SAVEA', 'Save-a-lot Markets', 2393.5)
# (10369, 'SPLIR', 'Split Rail Beer & Ale', 2390.4)
# (10598, 'RATTC', 'Rattlesnake Canyon Grocery', 2388.5)
# (10516, 'HUNGO', 'Hungry Owl All-Night Grocers', 2381.05)
# (10948, 'GODOS', 'Godos Cocina Típica', 2362.25)
# (10796, 'HILAA', 'HILARION-Abastos', 2341.36)
# (10522, 'LEHMS', 'Lehmanns Marktstand', 2318.24)
# (10519, 'CHOPS', 'Chop-suey Chinese', 2314.2)
# (10746, 'CHOPS', 'Chop-suey Chinese', 2311.7)
# (10766, 'OTTIK', 'Ottilies Käseladen', 2310.0)
# (10670, 'FRANK', 'Frankenversand', 2301.75)
# (10991, 'QUICK', 'QUICK-Stop', 2296.0)
# (10344, 'WHITC', 'White Clover Markets', 2296.0)
# (10764, 'ERNSH', 'Ernst Handel', 2286.0)
# (10601, 'HILAA', 'HILARION-Abastos', 2285.0)
# (10804, 'SEVES', 'Seven Seas Imports', 2278.4)
# (10930, 'SUPRD', 'Suprêmes délices', 2255.5)
# (10583, 'WARTH', 'Wartian Herkku', 2237.5)
# (10977, 'FOLKO', 'Folk och fä HB', 2233.0)
# (10855, 'OLDWO', 'Old World Delicatessen', 2227.89)
# (10384, 'BERGS', 'Berglunds snabbköp', 2222.4)
# (10533, 'FOLKO', 'Folk och fä HB', 2222.2)
# (10986, 'OCEAN', 'Océano Atlántico Ltda.', 2220.0)
# (10714, 'SAVEA', 'Save-a-lot Markets', 2205.75)
# (10748, 'SAVEA', 'Save-a-lot Markets', 2196.0)
# (10290, 'COMMI', 'Comércio Mineiro', 2169.0)
# (11028, 'KOENE', 'Königlich Essen', 2160.0)
# (10795, 'ERNSH', 'Ernst Handel', 2158.0)
# (10575, 'MORGK', 'Morgenstern Gesundkost', 2147.4)
# (10558, 'AROUT', 'Around the Horn', 2142.9)
# (10413, 'LAMAI', "La maison d'Asie", 2123.2)
# (10395, 'HILAA', 'HILARION-Abastos', 2122.92)
# (10419, 'RICSU', 'Richter Supermarkt', 2097.6)
# (10314, 'RATTC', 'Rattlesnake Canyon Grocery', 2094.3)
# (10390, 'ERNSH', 'Ernst Handel', 2090.88)
# (10892, 'MAISD', 'Maison Dewey', 2090.0)
# (10573, 'ANTON', 'Antonio Moreno Taquería', 2082.0)
# (10693, 'WHITC', 'White Clover Markets', 2071.2)
# (10872, 'GODOS', 'Godos Cocina Típica', 2058.46)
# (10641, 'HILAA', 'HILARION-Abastos', 2054.0)
# (10964, 'SPECD', 'Spécialités du monde', 2052.5)
# (10503, 'HUNGO', 'Hungry Owl All-Night Grocers', 2048.5)
# (10857, 'BERGS', 'Berglunds snabbköp', 2048.21)
# (10361, 'QUICK', 'QUICK-Stop', 2046.24)
# (10273, 'QUICK', 'QUICK-Stop', 2037.28)
# (10335, 'HUNGO', 'Hungry Owl All-Night Grocers', 2036.16)
# (10773, 'ERNSH', 'Ernst Handel', 2030.4)
# (11068, 'QUEEN', 'Queen Cozinha', 2027.08)
# (10985, 'HUNGO', 'Hungry Owl All-Night Grocers', 2023.38)
# (10452, 'SAVEA', 'Save-a-lot Markets', 2018.5)
# (10436, 'BLONP', 'Blondesddsl père et fils', 1994.52)
# (10593, 'LEHMS', 'Lehmanns Marktstand', 1994.4)
# (10756, 'SPLIR', 'Split Rail Beer & Ale', 1990.0)
# (10871, 'BONAP', "Bon app'", 1979.23)
# (10830, 'TRADH', 'Tradição Hipermercados', 1974.0)
# (11024, 'EASTC', 'Eastern Connection', 1966.81)
# (10877, 'RICAR', 'Ricardo Adocicados', 1955.13)
# (10755, 'BONAP', "Bon app'", 1948.5)
# (10541, 'HANAR', 'Hanari Carnes', 1946.52)
# (10513, 'WANDK', 'Die Wandernde Kuh', 1942.0)
# (10535, 'ANTON', 'Antonio Moreno Taquería', 1940.85)
# (10838, 'LINOD', 'LINO-Delicateses', 1938.38)
# (10921, 'VAFFE', 'Vaffeljernet', 1936.0)
# (10663, 'BONAP', "Bon app'", 1930.4)
# (10904, 'WHITC', 'White Clover Markets', 1924.25)
# (10868, 'QUEEN', 'Queen Cozinha', 1920.6)
# (10747, 'PICCO', 'Piccolo und mehr', 1912.85)
# (10396, 'FRANK', 'Frankenversand', 1903.8)
# (10706, 'OLDWO', 'Old World Delicatessen', 1893.0)
# (10431, 'BOTTM', 'Bottom-Dollar Markets', 1892.25)
# (10731, 'CHOPS', 'Chop-suey Chinese', 1890.5)
# (10294, 'RATTC', 'Rattlesnake Canyon Grocery', 1887.6)
# (10997, 'LILAS', 'LILA-Supermercado', 1885.0)
# (10263, 'ERNSH', 'Ernst Handel', 1873.8)
# (10249, 'TOMSP', 'Toms Spezialitäten', 1863.4)
# (10729, 'LINOD', 'LINO-Delicateses', 1850.0)
# (10342, 'FRANK', 'Frankenversand', 1840.64)
# (10449, 'BLONP', 'Blondesddsl père et fils', 1838.2)
# (11059, 'RICAR', 'Ricardo Adocicados', 1838.0)
# (10924, 'BERGS', 'Berglunds snabbköp', 1835.7)
# (10389, 'BOTTM', 'Bottom-Dollar Markets', 1832.8)
# (10406, 'QUEEN', 'Queen Cozinha', 1830.78)
# (10791, 'FRANK', 'Frankenversand', 1829.76)
# (10537, 'RICSU', 'Richter Supermarkt', 1823.8)
# (10470, 'BONAP', "Bon app'", 1820.8)
# (10418, 'QUICK', 'QUICK-Stop', 1814.8)
# (11002, 'SAVEA', 'Save-a-lot Markets', 1811.1)
# (10327, 'FOLKO', 'Folk och fä HB', 1810.0)
# (10984, 'SAVEA', 'Save-a-lot Markets', 1809.75)
# (10547, 'SEVES', 'Seven Seas Imports', 1792.8)
# (10442, 'ERNSH', 'Ernst Handel', 1792.0)
# (10932, 'BONAP', "Bon app'", 1788.63)
# (10814, 'VICTE', 'Victuailles en stock', 1788.45)
# (10332, 'MEREP', 'Mère Paillarde', 1786.88)
# (10650, 'FAMIA', 'Familia Arquibaldo', 1779.2)
# (11041, 'CHOPS', 'Chop-suey Chinese', 1773.0)
# (10684, 'OTTIK', 'Ottilies Käseladen', 1768.0)
# (10399, 'VAFFE', 'Vaffeljernet', 1765.6)
# (10829, 'ISLAT', 'Island Trading', 1764.0)
# (10957, 'HILAA', 'HILARION-Abastos', 1762.7)
# (10309, 'HUNGO', 'Hungry Owl All-Night Grocers', 1762.0)
# (10566, 'BLONP', 'Blondesddsl père et fils', 1761.0)
# (10441, 'OLDWO', 'Old World Delicatessen', 1755.0)
# (11035, 'SUPRD', 'Suprêmes délices', 1754.5)
# (10285, 'QUICK', 'QUICK-Stop', 1743.36)
# (10971, 'FRANR', 'France restauration', 1733.06)
# (10554, 'OTTIK', 'Ottilies Käseladen', 1728.52)
# (11055, 'HILAA', 'HILARION-Abastos', 1727.5)
# (10420, 'WELLI', 'Wellington Importadora', 1707.84)
# (10660, 'HUNGC', 'Hungry Coyote Import Store', 1701.0)
# (10812, 'REGGC', 'Reggiani Caseifici', 1692.8)
# (11036, 'DRACD', 'Drachenblut Delikatessen', 1692.0)
# (10368, 'ERNSH', 'Ernst Handel', 1689.78)
# (10769, 'VAFFE', 'Vaffeljernet', 1684.27)
# (10551, 'FURIB', 'Furia Bacalhau e Frutos do Mar', 1677.3)
# (10954, 'LINOD', 'LINO-Delicateses', 1659.54)
# (10459, 'VICTE', 'Victuailles en stock', 1659.2)
# (10330, 'LILAS', 'LILA-Supermercado', 1649.0)
# (10536, 'LEHMS', 'Lehmanns Marktstand', 1645.0)
# (10758, 'RICSU', 'Richter Supermarkt', 1644.6)
# (10707, 'AROUT', 'Around the Horn', 1641.0)
# (10700, 'SAVEA', 'Save-a-lot Markets', 1638.4)
# (10751, 'RICSU', 'Richter Supermarkt', 1631.48)
# (10869, 'SEVES', 'Seven Seas Imports', 1630.0)
# (11070, 'LEHMS', 'Lehmanns Marktstand', 1629.98)
# (10727, 'REGGC', 'Reggiani Caseifici', 1624.5)
# (10408, 'FOLIG', 'Folies gourmandes', 1622.4)
# (10346, 'RATTC', 'Rattlesnake Canyon Grocery', 1618.88)
# (10258, 'ERNSH', 'Ernst Handel', 1614.88)
# (10312, 'WANDK', 'Die Wandernde Kuh', 1614.8)
# (10464, 'FURIB', 'Furia Bacalhau e Frutos do Mar', 1609.28)
# (10404, 'MAGAA', 'Magazzini Alimentari Riuniti', 1591.25)
# (10750, 'WARTH', 'Wartian Herkku', 1590.56)
# (10457, 'KOENE', 'Königlich Essen', 1584.0)
# (10343, 'LEHMS', 'Lehmanns Marktstand', 1584.0)
# (10485, 'LINOD', 'LINO-Delicateses', 1584.0)
# (11018, 'LONEP', 'Lonesome Pine Restaurant', 1575.0)
# (10722, 'SAVEA', 'Save-a-lot Markets', 1570.0)
# (10799, 'KOENE', 'Königlich Essen', 1553.5)
# (10250, 'HANAR', 'Hanari Carnes', 1552.6)
# (10362, 'BONAP', "Bon app'", 1549.6)
# (10553, 'WARTH', 'Wartian Herkku', 1546.3)
# (10878, 'QUICK', 'QUICK-Stop', 1539.0)
# (10461, 'LILAS', 'LILA-Supermercado', 1538.7)
# (10667, 'ERNSH', 'Ernst Handel', 1536.8)
# (10645, 'HANAR', 'Hanari Carnes', 1535.0)
# (10786, 'QUEEN', 'Queen Cozinha', 1531.08)
# (10765, 'QUICK', 'QUICK-Stop', 1515.6)
# (10488, 'FRANK', 'Frankenversand', 1512.0)
# (10475, 'SUPRD', 'Suprêmes délices', 1505.18)
# (10260, 'OTTIK', 'Ottilies Käseladen', 1504.65)
# (10543, 'LILAS', 'LILA-Supermercado', 1504.5)
# (10626, 'BERGS', 'Berglunds snabbköp', 1503.6)
# (10527, 'QUICK', 'QUICK-Stop', 1503.0)
# (10572, 'BERGS', 'Berglunds snabbköp', 1501.08)
# (11023, 'BSBEV', "B's Beverages", 1500.0)
# (10880, 'FOLKO', 'Folk och fä HB', 1500.0)
# (10734, 'GOURL', 'Gourmet Lanchonetes', 1498.35)
# (10325, 'KOENE', 'Königlich Essen', 1497.0)
# (10278, 'BERGS', 'Berglunds snabbköp', 1488.8)
# (10784, 'MAGAA', 'Magazzini Alimentari Riuniti', 1488.0)
# (11046, 'WANDK', 'Die Wandernde Kuh', 1485.8)
# (10603, 'SAVEA', 'Save-a-lot Markets', 1483.0)
# (10768, 'AROUT', 'Around the Horn', 1477.0)
# (10481, 'RICAR', 'Ricardo Adocicados', 1472.0)
# (10800, 'SEVES', 'Seven Seas Imports', 1468.93)
# (10733, 'BERGS', 'Berglunds snabbköp', 1459.0)
# (10272, 'RATTC', 'Rattlesnake Canyon Grocery', 1456.0)
# (10918, 'BOTTM', 'Bottom-Dollar Markets', 1447.5)
# (10646, 'HUNGO', 'Hungry Owl All-Night Grocers', 1446.0)
# (10253, 'HANAR', 'Hanari Carnes', 1444.8)
# (10783, 'HANAR', 'Hanari Carnes', 1442.5)
# (10429, 'HUNGO', 'Hungry Owl All-Night Grocers', 1441.37)
# (10392, 'PICCO', 'Piccolo und mehr', 1440.0)
# (10649, 'MAISD', 'Maison Dewey', 1434.0)
# (10834, 'TRADH', 'Tradição Hipermercados', 1432.71)
# (10675, 'FRANK', 'Frankenversand', 1423.0)
# (10297, 'BLONP', 'Blondesddsl père et fils', 1420.0)
# (10740, 'WHITC', 'White Clover Markets', 1416.0)
# (10283, 'LILAS', 'LILA-Supermercado', 1414.8)
# (10499, 'LILAS', 'LILA-Supermercado', 1412.0)
# (10808, 'OLDWO', 'Old World Delicatessen', 1411.0)
# (10968, 'ERNSH', 'Ernst Handel', 1408.0)
# (10946, 'VAFFE', 'Vaffeljernet', 1407.5)
# (10686, 'PICCO', 'Piccolo und mehr', 1404.45)
# (10617, 'GREAL', 'Great Lakes Food Market', 1402.5)
# (11022, 'HANAR', 'Hanari Carnes', 1402.0)
# (10624, 'THECR', 'The Cracker Box', 1393.24)
# (10504, 'WHITC', 'White Clover Markets', 1388.5)
# (10497, 'LEHMS', 'Lehmanns Marktstand', 1380.6)
# (10884, 'LETSS', "Let's Stop N Shop", 1378.07)
# (10270, 'WARTH', 'Wartian Herkku', 1376.0)
# (10644, 'WELLI', 'Wellington Importadora', 1371.8)
# (10373, 'HUNGO', 'Hungry Owl All-Night Grocers', 1366.4)
# (10989, 'QUEDE', 'Que Delícia', 1353.6)
# (11063, 'HUNGO', 'Hungry Owl All-Night Grocers', 1342.95)
# (10623, 'FRANK', 'Frankenversand', 1336.95)
# (10779, 'MORGK', 'Morgenstern Gesundkost', 1335.0)
# (11052, 'HANAR', 'Hanari Carnes', 1332.0)
# (10471, 'BSBEV', "B's Beverages", 1328.0)
# (10635, 'MAGAA', 'Magazzini Alimentari Riuniti', 1326.23)
# (10380, 'HUNGO', 'Hungry Owl All-Night Grocers', 1313.82)
# (11045, 'BOTTM', 'Bottom-Dollar Markets', 1309.5)
# (10978, 'MAISD', 'Maison Dewey', 1303.2)
# (10728, 'QUEEN', 'Queen Cozinha', 1296.75)
# (10715, 'BONAP', "Bon app'", 1296.0)
# (10292, 'TRADH', 'Tradição Hipermercados', 1296.0)
# (10665, 'LONEP', 'Lonesome Pine Restaurant', 1295.0)
# (10664, 'FURIB', 'Furia Bacalhau e Frutos do Mar', 1288.39)
# (10681, 'GREAL', 'Great Lakes Food Market', 1287.4)
# (11029, 'CHOPS', 'Chop-suey Chinese', 1286.8)
# (10486, 'HILAA', 'HILARION-Abastos', 1272.0)
# (10717, 'FRANK', 'Frankenversand', 1270.75)
# (10680, 'OLDWO', 'Old World Delicatessen', 1261.88)
# (10619, 'MEREP', 'Mère Paillarde', 1260.0)
# (11077, 'RATTC', 'Rattlesnake Canyon Grocery', 1255.72)
# (10474, 'PERIC', 'Pericles Comidas clásicas', 1249.1)
# (10564, 'RATTC', 'Rattlesnake Canyon Grocery', 1234.05)
# (10712, 'HUNGO', 'Hungry Owl All-Night Grocers', 1233.48)
# (10388, 'SEVES', 'Seven Seas Imports', 1228.8)
# (10659, 'QUEEN', 'Queen Cozinha', 1227.02)
# (10885, 'SUPRD', 'Suprêmes délices', 1209.0)
# (10277, 'MORGK', 'Morgenstern Gesundkost', 1200.8)
# (10999, 'OTTIK', 'Ottilies Käseladen', 1197.95)
# (10995, 'PERIC', 'Pericles Comidas clásicas', 1196.0)
# (10421, 'QUEDE', 'Que Delícia', 1194.27)
# (10407, 'OTTIK', 'Ottilies Käseladen', 1194.0)
# (10803, 'WELLI', 'Wellington Importadora', 1193.01)
# (10319, 'TORTU', 'Tortuga Restaurante', 1191.2)
# (10627, 'SAVEA', 'Save-a-lot Markets', 1185.75)
# (10596, 'WHITC', 'White Clover Markets', 1180.88)
# (10265, 'BLONP', 'Blondesddsl père et fils', 1176.0)
# (10929, 'FRANK', 'Frankenversand', 1174.75)
# (10284, 'LEHMS', 'Lehmanns Marktstand', 1170.38)
# (10328, 'FURIB', 'Furia Bacalhau e Frutos do Mar', 1168.0)
# (10357, 'LILAS', 'LILA-Supermercado', 1167.68)
# (10557, 'LEHMS', 'Lehmanns Marktstand', 1152.5)
# (10526, 'WARTH', 'Wartian Herkku', 1151.4)
# (10820, 'RATTC', 'Rattlesnake Canyon Grocery', 1140.0)
# (10606, 'TRADH', 'Tradição Hipermercados', 1130.4)
# (10919, 'LINOD', 'LINO-Delicateses', 1122.8)
# (10257, 'HILAA', 'HILARION-Abastos', 1119.9)
# (10961, 'QUEEN', 'Queen Cozinha', 1119.9)
# (10303, 'GODOS', 'Godos Cocina Típica', 1117.8)
# (10370, 'CHOPS', 'Chop-suey Chinese', 1117.6)
# (10846, 'SUPRD', 'Suprêmes délices', 1112.0)
# (10356, 'WANDK', 'Die Wandernde Kuh', 1106.4)
# (10268, 'GROSR', 'GROSELLA-Restaurante', 1101.2)
# (10590, 'MEREP', 'Mère Paillarde', 1101.0)
# (10966, 'CHOPS', 'Chop-suey Chinese', 1098.46)
# (10866, 'BERGS', 'Berglunds snabbköp', 1096.2)
# (10653, 'FRANK', 'Frankenversand', 1083.15)
# (10749, 'ISLAT', 'Island Trading', 1080.0)
# (10859, 'FRANK', 'Frankenversand', 1078.69)
# (10439, 'MEREP', 'Mère Paillarde', 1078.0)
# (10560, 'FRANK', 'Frankenversand', 1072.42)
# (10837, 'BERGS', 'Berglunds snabbköp', 1064.5)
# (10608, 'TOMSP', 'Toms Spezialitäten', 1064.0)
# (10387, 'SANTG', 'Santé Gourmet', 1058.4)
# (10296, 'LILAS', 'LILA-Supermercado', 1050.6)
# (10472, 'SEVES', 'Seven Seas Imports', 1036.8)
# (10444, 'BERGS', 'Berglunds snabbköp', 1031.7)
# (10825, 'DRACD', 'Drachenblut Delikatessen', 1030.76)
# (11026, 'FRANS', 'Franchi S.p.A.', 1030.0)
# (10944, 'BOTTM', 'Bottom-Dollar Markets', 1025.33)
# (10423, 'GOURL', 'Gourmet Lanchonetes', 1020.0)
# (10982, 'BOTTM', 'Bottom-Dollar Markets', 1014.0)
# (10580, 'OTTIK', 'Ottilies Käseladen', 1013.74)
# (10736, 'HUNGO', 'Hungry Owl All-Night Grocers', 997.0)
# (10696, 'WHITC', 'White Clover Markets', 996.0)
# (10326, 'BOLID', 'Bólido Comidas preparadas', 982.0)
# (10781, 'WARTH', 'Wartian Herkku', 975.88)
# (10842, 'TORTU', 'Tortuga Restaurante', 975.0)
# (10849, 'KOENE', 'Königlich Essen', 967.82)
# (10411, 'BOTTM', 'Bottom-Dollar Markets', 966.8)
# (10563, 'RICAR', 'Ricardo Adocicados', 965.0)
# (10469, 'WHITC', 'White Clover Markets', 956.67)
# (10304, 'TORTU', 'Tortuga Restaurante', 954.4)
# (10364, 'EASTC', 'Eastern Connection', 950.0)
# (10529, 'MAISD', 'Maison Dewey', 946.0)
# (10994, 'VAFFE', 'Vaffeljernet', 940.5)
# (10901, 'HILAA', 'HILARION-Abastos', 934.5)
# (10338, 'OLDWO', 'Old World Delicatessen', 934.5)
# (11011, 'ALFKI', 'Alfreds Futterkiste', 933.5)
# (10903, 'HANAR', 'Hanari Carnes', 932.05)
# (10828, 'RANCH', 'Rancho grande', 932.0)
# (10848, 'CONSH', 'Consolidated Holdings', 931.5)
# (11066, 'WHITC', 'White Clover Markets', 928.75)
# (10721, 'QUICK', 'QUICK-Stop', 923.88)
# (10933, 'ISLAT', 'Island Trading', 920.6)
# (10671, 'FRANR', 'France restauration', 920.1)
# (10876, 'BONAP', "Bon app'", 917.0)
# (10447, 'RICAR', 'Ricardo Adocicados', 914.4)
# (10494, 'COMMI', 'Comércio Mineiro', 912.0)
# (10976, 'HILAA', 'HILARION-Abastos', 912.0)
# (10967, 'TOMSP', 'Toms Spezialitäten', 910.4)
# (10833, 'OTTIK', 'Ottilies Käseladen', 906.93)
# (11000, 'RATTC', 'Rattlesnake Canyon Grocery', 903.75)
# (10630, 'KOENE', 'Königlich Essen', 903.6)
# (10383, 'AROUT', 'Around the Horn', 899.0)
# (10882, 'SAVEA', 'Save-a-lot Markets', 892.64)
# (10569, 'RATTC', 'Rattlesnake Canyon Grocery', 890.0)
# (10487, 'QUEEN', 'Queen Cozinha', 889.7)
# (10552, 'HILAA', 'HILARION-Abastos', 880.5)
# (10692, 'ALFKI', 'Alfreds Futterkiste', 878.0)
# (11027, 'BOTTM', 'Bottom-Dollar Markets', 877.72)
# (10333, 'WARTH', 'Wartian Herkku', 877.2)
# (10774, 'FOLKO', 'Folk och fä HB', 868.75)
# (10377, 'SEVES', 'Seven Seas Imports', 863.6)
# (10902, 'FOLKO', 'Folk och fä HB', 863.43)
# (10379, 'QUEDE', 'Que Delícia', 863.28)
# (10690, 'HANAR', 'Hanari Carnes', 862.5)
# (10890, 'DUMON', 'Du monde entier', 860.1)
# (11058, 'BLAUS', 'Blauer See Delikatessen', 858.0)
# (10911, 'GODOS', 'Godos Cocina Típica', 858.0)
# (10403, 'ERNSH', 'Ernst Handel', 855.02)
# (10811, 'LINOD', 'LINO-Delicateses', 852.0)
# (10492, 'BOTTM', 'Bottom-Dollar Markets', 851.2)
# (10433, 'PRINI', 'Princesa Isabel Vinhos', 851.2)
# (10293, 'TORTU', 'Tortuga Restaurante', 848.7)
# (10965, 'OLDWO', 'Old World Delicatessen', 848.0)
# (10835, 'ALFKI', 'Alfreds Futterkiste', 845.8)
# (10719, 'LETSS', "Let's Stop N Shop", 844.25)
# (10827, 'BONAP', "Bon app'", 843.0)
# (10576, 'TORTU', 'Tortuga Restaurante', 838.45)
# (10556, 'SIMOB', 'Simons bistro', 835.2)
# (10367, 'VAFFE', 'Vaffeljernet', 834.2)
# (10818, 'MAGAA', 'Magazzini Alimentari Riuniti', 833.0)
# (10839, 'TRADH', 'Tradição Hipermercados', 827.55)
# (10287, 'RICAR', 'Ricardo Adocicados', 819.0)
# (10525, 'BONAP', "Bon app'", 818.4)
# (11047, 'EASTC', 'Eastern Connection', 817.88)
# (10502, 'PERIC', 'Pericles Comidas clásicas', 816.3)
# (10643, 'ALFKI', 'Alfreds Futterkiste', 814.5)
# (10347, 'FAMIA', 'Familia Arquibaldo', 814.42)
# (10677, 'ANTON', 'Antonio Moreno Taquería', 813.36)
# (10591, 'VAFFE', 'Vaffeljernet', 812.5)
# (11050, 'FOLKO', 'Folk och fä HB', 810.0)
# (10611, 'WOLZA', 'Wolski  Zajazd', 808.0)
# (10587, 'QUEDE', 'Que Delícia', 807.38)
# (10697, 'LINOD', 'LINO-Delicateses', 805.42)
# (10410, 'BOTTM', 'Bottom-Dollar Markets', 802.0)
# (10685, 'GOURL', 'Gourmet Lanchonetes', 801.1)
# (10927, 'LACOR', "La corne d'abondance", 800.0)
# (10931, 'RICSU', 'Richter Supermarkt', 799.2)
# (10532, 'EASTC', 'Eastern Connection', 796.35)
# (11076, 'BONAP', "Bon app'", 792.75)
# (10958, 'OCEAN', 'Océano Atlántico Ltda.', 781.0)
# (10913, 'QUEEN', 'Queen Cozinha', 768.75)
# (10574, 'TRAIH', "Trail's Head Gourmet Provisioners", 764.3)
# (10621, 'ISLAT', 'Island Trading', 758.5)
# (10480, 'FOLIG', 'Folies gourmandes', 756.0)
# (10301, 'WANDK', 'Die Wandernde Kuh', 755.0)
# (10896, 'MAISD', 'Maison Dewey', 750.5)
# (10507, 'ANTON', 'Antonio Moreno Taquería', 749.06)
# (10923, 'LAMAI', "La maison d'Asie", 748.8)
# (10922, 'HANAR', 'Hanari Carnes', 742.5)
# (10744, 'VAFFE', 'Vaffeljernet', 736.0)
# (10844, 'PICCO', 'Piccolo und mehr', 735.0)
# (11038, 'SUPRD', 'Suprêmes délices', 732.6)
# (10788, 'QUICK', 'QUICK-Stop', 731.5)
# (10826, 'BLONP', 'Blondesddsl père et fils', 730.0)
# (10790, 'GOURL', 'Gourmet Lanchonetes', 722.5)
# (10983, 'SAVEA', 'Save-a-lot Markets', 720.9)
# (10780, 'LILAS', 'LILA-Supermercado', 720.0)
# (10416, 'WARTH', 'Wartian Herkku', 720.0)
# (10597, 'PICCO', 'Piccolo und mehr', 718.08)
# (10468, 'KOENE', 'Königlich Essen', 717.6)
# (10975, 'BOTTM', 'Bottom-Dollar Markets', 717.5)
# (10397, 'PRINI', 'Princesa Isabel Vinhos', 716.72)
# (10463, 'SUPRD', 'Suprêmes délices', 713.3)
# (10943, 'BSBEV', "B's Beverages", 711.0)
# (10875, 'BERGS', 'Berglunds snabbköp', 709.55)
# (10640, 'WANDK', 'Die Wandernde Kuh', 708.75)
# (10716, 'RANCH', 'Rancho grande', 706.0)
# (10642, 'SIMOB', 'Simons bistro', 696.0)
# (10264, 'FOLKO', 'Folk och fä HB', 695.63)
# (10385, 'SPLIR', 'Split Rail Beer & Ale', 691.2)
# (10916, 'RANCH', 'Rancho grande', 686.7)
# (10998, 'WOLZA', 'Wolski  Zajazd', 686.0)
# (10550, 'GODOS', 'Godos Cocina Típica', 683.3)
# (10821, 'SPLIR', 'Split Rail Beer & Ale', 678.0)
# (10956, 'BLAUS', 'Blauer See Delikatessen', 677.0)
# (10909, 'SANTG', 'Santé Gourmet', 670.0)
# (10483, 'WHITC', 'White Clover Markets', 668.8)
# (10908, 'REGGC', 'Reggiani Caseifici', 663.1)
# (10856, 'ANTON', 'Antonio Moreno Taquería', 660.0)
# (10679, 'BLONP', 'Blondesddsl père et fils', 660.0)
# (10726, 'EASTC', 'Eastern Connection', 655.0)
# (10251, 'VICTE', 'Victuailles en stock', 654.06)
# (10427, 'PICCO', 'Piccolo und mehr', 651.0)
# (10858, 'LACOR', "La corne d'abondance", 649.0)
# (11010, 'REGGC', 'Reggiani Caseifici', 645.0)
# (10937, 'CACTU', 'Cactus Comidas para llevar', 644.8)
# (10269, 'WHITC', 'White Clover Markets', 642.2)
# (10350, 'LAMAI', "La maison d'Asie", 642.06)
# (10695, 'WILMK', 'Wilman Kala', 642.0)
# (10565, 'MEREP', 'Mère Paillarde', 639.9)
# (10724, 'MEREP', 'Mère Paillarde', 638.5)
# (10939, 'MAGAA', 'Magazzini Alimentari Riuniti', 637.5)
# (10647, 'QUEDE', 'Que Delícia', 636.0)
# (11020, 'OTTIK', 'Ottilies Käseladen', 632.4)
# (10435, 'CONSH', 'Consolidated Holdings', 631.6)
# (10636, 'WARTH', 'Wartian Herkku', 629.5)
# (10850, 'VICTE', 'Victuailles en stock', 629.0)
# (10668, 'WANDK', 'Die Wandernde Kuh', 625.27)
# (10853, 'BLAUS', 'Blauer See Delikatessen', 625.0)
# (11015, 'SANTG', 'Santé Gourmet', 622.35)
# (10935, 'WELLI', 'Wellington Importadora', 619.5)
# (11009, 'GODOS', 'Godos Cocina Típica', 616.5)
# (10763, 'FOLIG', 'Folies gourmandes', 616.0)
# (10280, 'BERGS', 'Berglunds snabbköp', 613.2)
# (10879, 'WILMK', 'Wilman Kala', 611.3)
# (10493, 'LAMAI', "La maison d'Asie", 608.4)
# (10300, 'MAGAA', 'Magazzini Alimentari Riuniti', 608.0)
# (10888, 'GODOS', 'Godos Cocina Típica', 605.0)
# (10656, 'GREAL', 'Great Lakes Food Market', 604.22)
# (10813, 'RICAR', 'Ricardo Adocicados', 602.4)
# (10654, 'BERGS', 'Berglunds snabbköp', 601.83)
# (10704, 'QUEEN', 'Queen Cozinha', 595.5)
# (10584, 'BLONP', 'Blondesddsl père et fils', 593.75)
# (11044, 'WOLZA', 'Wolski  Zajazd', 591.6)
# (10632, 'WANDK', 'Die Wandernde Kuh', 589.0)
# (11005, 'WILMK', 'Wilman Kala', 586.0)
# (10262, 'RATTC', 'Rattlesnake Canyon Grocery', 584.0)
# (10862, 'LEHMS', 'Lehmanns Marktstand', 581.0)
# (10498, 'HILAA', 'HILARION-Abastos', 575.0)
# (10669, 'SIMOB', 'Simons bistro', 570.0)
# (10577, 'TRAIH', "Trail's Head Gourmet Provisioners", 569.0)
# (10354, 'PERIC', 'Pericles Comidas clásicas', 568.8)
# (10594, 'OLDWO', 'Old World Delicatessen', 565.5)
# (10661, 'HUNGO', 'Hungry Owl All-Night Grocers', 562.6)
# (10996, 'QUICK', 'QUICK-Stop', 560.0)
# (10942, 'REGGC', 'Reggiani Caseifici', 560.0)
# (10622, 'RICAR', 'Ricardo Adocicados', 560.0)
# (10477, 'PRINI', 'Princesa Isabel Vinhos', 558.0)
# (10456, 'KOENE', 'Königlich Essen', 557.6)
# (10254, 'CHOPS', 'Chop-suey Chinese', 556.62)
# (10571, 'ERNSH', 'Ernst Handel', 550.59)
# (10720, 'QUEDE', 'Que Delícia', 550.0)
# (10915, 'TORTU', 'Tortuga Restaurante', 539.5)
# (11034, 'OLDWO', 'Old World Delicatessen', 539.4)
# (10274, 'VINET', 'Vins et alcools Chevalier', 538.6)
# (10914, 'QUEEN', 'Queen Cozinha', 537.5)
# (10735, 'LETSS', "Let's Stop N Shop", 536.4)
# (10676, 'TORTU', 'Tortuga Restaurante', 534.85)
# (10512, 'FAMIA', 'Familia Arquibaldo', 525.3)
# (11048, 'BOTTM', 'Bottom-Dollar Markets', 525.0)
# (10500, 'LAMAI', "La maison d'Asie", 523.26)
# (10559, 'BLONP', 'Blondesddsl père et fils', 520.41)
# (10860, 'FRANR', 'France restauration', 519.0)
# (10256, 'WELLI', 'Wellington Importadora', 517.8)
# (10443, 'REGGC', 'Reggiani Caseifici', 517.44)
# (10315, 'ISLAT', 'Island Trading', 516.8)
# (10592, 'LEHMS', 'Lehmanns Marktstand', 516.47)
# (10320, 'WARTH', 'Wartian Herkku', 516.0)
# (10926, 'ANATR', 'Ana Trujillo Emparedados y helados', 514.4)
# (11061, 'GREAL', 'Great Lakes Food Market', 510.0)
# (10761, 'RATTC', 'Rattlesnake Canyon Grocery', 507.0)
# (10934, 'LEHMS', 'Lehmanns Marktstand', 500.0)
# (10639, 'SANTG', 'Santé Gourmet', 500.0)
# (10306, 'ROMEY', 'Romero y tomillo', 498.5)
# (11075, 'RICSU', 'Richter Supermarkt', 498.1)
# (10291, 'QUEDE', 'Que Delícia', 497.52)
# (10599, 'BSBEV', "B's Beverages", 493.0)
# (11016, 'AROUT', 'Around the Horn', 491.5)
# (10562, 'REGGC', 'Reggiani Caseifici', 488.7)
# (10432, 'SPLIR', 'Split Rail Beer & Ale', 485.0)
# (11071, 'LILAS', 'LILA-Supermercado', 484.5)
# (10730, 'BONAP', "Bon app'", 484.26)
# (10355, 'AROUT', 'Around the Horn', 480.0)
# (10600, 'HUNGC', 'Hungry Coyote Import Store', 479.8)
# (10625, 'ANATR', 'Ana Trujillo Emparedados y helados', 479.75)
# (10289, 'BSBEV', "B's Beverages", 479.4)
# (10578, 'BSBEV', "B's Beverages", 477.0)
# (10819, 'CACTU', 'Cactus Comidas para llevar', 477.0)
# (10925, 'HANAR', 'Hanari Carnes', 475.15)
# (10832, 'LAMAI', "La maison d'Asie", 475.11)
# (10689, 'BERGS', 'Berglunds snabbköp', 472.5)
# (10952, 'ALFKI', 'Alfreds Futterkiste', 471.2)
# (10478, 'VICTE', 'Victuailles en stock', 471.2)
# (10542, 'KOENE', 'Königlich Essen', 469.11)
# (10723, 'WHITC', 'White Clover Markets', 468.45)
# (10534, 'LEHMS', 'Lehmanns Marktstand', 465.7)
# (10614, 'BLAUS', 'Blauer See Delikatessen', 464.0)
# (10374, 'WOLZA', 'Wolski  Zajazd', 459.0)
# (10951, 'RICSU', 'Richter Supermarkt', 458.75)
# (10936, 'GREAL', 'Great Lakes Food Market', 456.0)
# (10438, 'TOMSP', 'Toms Spezialitäten', 454.0)
# (10910, 'WILMK', 'Wilman Kala', 452.9)
# (10628, 'BLONP', 'Blondesddsl père et fils', 450.0)
# (10261, 'QUEDE', 'Que Delícia', 448.0)
# (10363, 'DRACD', 'Drachenblut Delikatessen', 447.2)
# (10798, 'ISLAT', 'Island Trading', 446.6)
# (10448, 'RANCH', 'Rancho grande', 443.4)
# (10394, 'HUNGC', 'Hungry Coyote Import Store', 442.0)
# (10863, 'HILAA', 'HILARION-Abastos', 441.15)
# (10248, 'VINET', 'Vins et alcools Chevalier', 440.0)
# (10806, 'VICTE', 'Victuailles en stock', 439.6)
# (10489, 'PICCO', 'Piccolo und mehr', 439.2)
# (10974, 'SPLIR', 'Split Rail Beer & Ale', 439.0)
# (10358, 'LAMAI', "La maison d'Asie", 429.4)
# (10906, 'WOLZA', 'Wolski  Zajazd', 427.5)
# (10450, 'VICTE', 'Victuailles en stock', 425.12)
# (10609, 'DUMON', 'Du monde entier', 424.0)
# (10307, 'LONEP', 'Lonesome Pine Restaurant', 424.0)
# (10797, 'DRACD', 'Drachenblut Delikatessen', 420.0)
# (10276, 'TORTU', 'Tortuga Restaurante', 420.0)
# (10544, 'LONEP', 'Lonesome Pine Restaurant', 417.2)
# (10506, 'KOENE', 'Königlich Essen', 415.8)
# (10673, 'WILMK', 'Wilman Kala', 412.35)
# (10453, 'AROUT', 'Around the Horn', 407.7)
# (11062, 'REGGC', 'Reggiani Caseifici', 406.4)
# (11042, 'COMMI', 'Comércio Mineiro', 405.75)
# (10365, 'ANTON', 'Antonio Moreno Taquería', 403.2)
# (10405, 'LINOD', 'LINO-Delicateses', 400.0)
# (10792, 'WOLZA', 'Wolski  Zajazd', 399.85)
# (10376, 'MEREP', 'Mère Paillarde', 399.0)
# (10651, 'WANDK', 'Die Wandernde Kuh', 397.8)
# (10437, 'WARTH', 'Wartian Herkku', 393.0)
# (10528, 'GREAL', 'Great Lakes Food Market', 392.2)
# (10920, 'AROUT', 'Around the Horn', 390.0)
# (10785, 'GROSR', 'GROSELLA-Restaurante', 387.5)
# (10484, 'BSBEV', "B's Beverages", 386.2)
# (10705, 'HILAA', 'HILARION-Abastos', 378.0)
# (10682, 'ANTON', 'Antonio Moreno Taquería', 375.5)
# (10648, 'RICAR', 'Ricardo Adocicados', 372.38)
# (10891, 'LEHMS', 'Lehmanns Marktstand', 368.93)
# (10917, 'ROMEY', 'Romero y tomillo', 365.89)
# (10348, 'WANDK', 'Die Wandernde Kuh', 363.6)
# (11013, 'ROMEY', 'Romero y tomillo', 361.0)
# (10732, 'BONAP', "Bon app'", 360.0)
# (10940, 'BONAP', "Bon app'", 360.0)
# (10425, 'LAMAI', "La maison d'Asie", 360.0)
# (11069, 'TORTU', 'Tortuga Restaurante', 360.0)
# (10539, 'BSBEV', "B's Beverages", 355.5)
# (10613, 'HILAA', 'HILARION-Abastos', 353.2)
# (10341, 'SIMOB', 'Simons bistro', 352.6)
# (10517, 'NORTS', 'North/South', 352.0)
# (10279, 'LEHMS', 'Lehmanns Marktstand', 351.0)
# (10299, 'RICAR', 'Ricardo Adocicados', 349.5)
# (10266, 'WARTH', 'Wartian Herkku', 346.56)
# (10771, 'ERNSH', 'Ernst Handel', 344.0)
# (10905, 'WELLI', 'Wellington Importadora', 342.0)
# (10426, 'GALED', 'Galería del gastrónomo', 338.2)
# (10375, 'HUNGC', 'Hungry Coyote Import Store', 338.0)
# (10873, 'WILMK', 'Wilman Kala', 336.8)
# (10310, 'THEBI', 'The Big Cheese', 336.0)
# (10412, 'WARTH', 'Wartian Herkku', 334.8)
# (10454, 'LAMAI', "La maison d'Asie", 331.2)
# (10702, 'ALFKI', 'Alfreds Futterkiste', 330.0)
# (10582, 'BLAUS', 'Blauer See Delikatessen', 330.0)
# (11006, 'GREAL', 'Great Lakes Food Market', 329.68)
# (11003, 'THECR', 'The Cracker Box', 326.0)
# (10434, 'FOLKO', 'Folk och fä HB', 321.12)
# (10759, 'ANATR', 'Ana Trujillo Emparedados y helados', 320.0)
# (10743, 'AROUT', 'Around the Horn', 319.2)
# (10409, 'OCEAN', 'Océano Atlántico Ltda.', 319.2)
# (10652, 'GOURL', 'Gourmet Lanchonetes', 318.83)
# (10579, 'LETSS', "Let's Stop N Shop", 317.75)
# (10794, 'QUEDE', 'Que Delícia', 314.76)
# (10581, 'FAMIA', 'Familia Arquibaldo', 310.0)
# (10874, 'GODOS', 'Godos Cocina Típica', 310.0)
# (11054, 'CACTU', 'Cactus Comidas para llevar', 305.0)
# (11073, 'PERIC', 'Pericles Comidas clásicas', 300.0)
# (10610, 'LAMAI', "La maison d'Asie", 299.25)
# (11004, 'MAISD', 'Maison Dewey', 295.38)
# (10275, 'MAGAA', 'Magazzini Alimentari Riuniti', 291.84)
# (10973, 'LACOR', "La corne d'abondance", 291.55)
# (10317, 'LONEP', 'Lonesome Pine Restaurant', 288.0)
# (10725, 'FAMIA', 'Familia Arquibaldo', 287.8)
# (10336, 'PRINI', 'Princesa Isabel Vinhos', 285.12)
# (10864, 'AROUT', 'Around the Horn', 282.0)
# (10495, 'LAUGB', 'Laughing Bacchus Wine Cellars', 278.0)
# (11049, 'GOURL', 'Gourmet Lanchonetes', 273.6)
# (11025, 'WARTH', 'Wartian Herkku', 270.0)
# (10311, 'DUMON', 'Du monde entier', 268.8)
# (11060, 'FRANS', 'Franchi S.p.A.', 266.0)
# (10960, 'HILAA', 'HILARION-Abastos', 265.35)
# (10491, 'FURIB', 'Furia Bacalhau e Frutos do Mar', 259.51)
# (10752, 'NORTS', 'North/South', 252.0)
# (10972, 'LACOR', "La corne d'abondance", 251.5)
# (10824, 'FOLKO', 'Folk och fä HB', 250.8)
# (10980, 'FOLKO', 'Folk och fä HB', 248.0)
# (10446, 'TOMSP', 'Toms Spezialitäten', 246.24)
# (10945, 'MORGK', 'Morgenstern Gesundkost', 245.0)
# (11014, 'LINOD', 'LINO-Delicateses', 243.18)
# (10318, 'ISLAT', 'Island Trading', 240.4)
# (10548, 'TOMSP', 'Toms Spezialitäten', 240.1)
# (10508, 'OTTIK', 'Ottilies Käseladen', 240.0)
# (10739, 'VINET', 'Vins et alcools Chevalier', 240.0)
# (10822, 'TRAIH', "Trail's Head Gourmet Provisioners", 237.9)
# (10770, 'HANAR', 'Hanari Carnes', 236.25)
# (10467, 'MAGAA', 'Magazzini Alimentari Riuniti', 235.2)
# (11074, 'SIMOB', 'Simons bistro', 232.09)
# (10604, 'FURIB', 'Furia Bacalhau e Frutos do Mar', 230.85)
# (10473, 'ISLAT', 'Island Trading', 230.4)
# (10741, 'AROUT', 'Around the Horn', 228.0)
# (10775, 'THECR', 'The Cracker Box', 228.0)
# (10521, 'CACTU', 'Cactus Comidas para llevar', 225.5)
# (10414, 'FAMIA', 'Familia Arquibaldo', 224.83)
# (10970, 'BOLID', 'Bólido Comidas preparadas', 224.0)
# (10777, 'GOURL', 'Gourmet Lanchonetes', 224.0)
# (10947, 'BSBEV', "B's Beverages", 220.0)
# (10466, 'COMMI', 'Comércio Mineiro', 216.0)
# (10840, 'LINOD', 'LINO-Delicateses', 211.2)
# (10545, 'LAZYK', 'Lazy K Kountry Store', 210.0)
# (11043, 'SPECD', 'Spécialités du monde', 210.0)
# (11040, 'GREAL', 'Great Lakes Food Market', 200.0)
# (10520, 'SANTG', 'Santé Gourmet', 200.0)
# (10428, 'REGGC', 'Reggiani Caseifici', 192.0)
# (10793, 'AROUT', 'Around the Horn', 191.1)
# (10496, 'TRADH', 'Tradição Hipermercados', 190.0)
# (11065, 'LILAS', 'LILA-Supermercado', 189.42)
# (10810, 'LAUGB', 'Laughing Bacchus Wine Cellars', 187.0)
# (10313, 'QUICK', 'QUICK-Stop', 182.4)
# (10476, 'HILAA', 'HILARION-Abastos', 180.48)
# (10708, 'THEBI', 'The Big Cheese', 180.4)
# (10460, 'FOLKO', 'Folk och fä HB', 176.1)
# (10445, 'BERGS', 'Berglunds snabbköp', 174.9)
# (10386, 'FAMIA', 'Familia Arquibaldo', 166.0)
# (10323, 'KOENE', 'Königlich Essen', 164.4)
# (10870, 'WOLZA', 'Wolski  Zajazd', 160.0)
# (10843, 'VICTE', 'Victuailles en stock', 159.0)
# (10462, 'CONSH', 'Consolidated Holdings', 156.0)
# (10282, 'ROMEY', 'Romero y tomillo', 155.4)
# (10568, 'GALED', 'Galería del gastrónomo', 155.0)
# (10655, 'REGGC', 'Reggiani Caseifici', 154.4)
# (10881, 'CACTU', 'Cactus Comidas para llevar', 150.0)
# (10501, 'BLAUS', 'Blauer See Delikatessen', 149.0)
# (10505, 'MEREP', 'Mère Paillarde', 147.9)
# (10482, 'LAZYK', 'Lazy K Kountry Store', 147.0)
# (10334, 'VICTE', 'Victuailles en stock', 144.8)
# (10321, 'ISLAT', 'Island Trading', 144.0)
# (10585, 'WELLI', 'Wellington Importadora', 142.5)
# (10349, 'SPLIR', 'Split Rail Beer & Ale', 141.6)
# (10809, 'WELLI', 'Wellington Importadora', 140.0)
# (10538, 'BSBEV', "B's Beverages", 139.8)
# (10737, 'VINET', 'Vins et alcools Chevalier', 139.8)
# (10928, 'GALED', 'Galería del gastrónomo', 137.5)
# (10509, 'BLAUS', 'Blauer See Delikatessen', 136.8)
# (10352, 'FURIB', 'Furia Bacalhau e Frutos do Mar', 136.3)
# (10366, 'GALED', 'Galería del gastrónomo', 136.0)
# (10959, 'GOURL', 'Gourmet Lanchonetes', 131.75)
# (10662, 'LONEP', 'Lonesome Pine Restaurant', 125.0)
# (10899, 'LILAS', 'LILA-Supermercado', 122.4)
# (10295, 'VINET', 'Vins et alcools Chevalier', 121.6)
# (10615, 'WILMK', 'Wilman Kala', 120.0)
# (10699, 'MORGK', 'Morgenstern Gesundkost', 114.0)
# (10381, 'LILAS', 'LILA-Supermercado', 112.0)
# (10322, 'PERIC', 'Pericles Comidas clásicas', 112.0)
# (10950, 'MAGAA', 'Magazzini Alimentari Riuniti', 110.0)
# (10531, 'OCEAN', 'Océano Atlántico Ltda.', 110.0)
# (10907, 'SPECD', 'Spécialités du monde', 108.5)
# (10969, 'COMMI', 'Comércio Mineiro', 108.0)
# (10378, 'FOLKO', 'Folk och fä HB', 103.2)
# (10415, 'HUNGC', 'Hungry Coyote Import Store', 102.4)
# (10259, 'CENTC', 'Centro comercial Moctezuma', 100.8)
# (10867, 'LONEP', 'Lonesome Pine Restaurant', 98.4)
# (10778, 'BERGS', 'Berglunds snabbköp', 96.5)
# (10710, 'FRANS', 'Franchi S.p.A.', 93.5)
# (10308, 'ANATR', 'Ana Trujillo Emparedados y helados', 88.8)
# (10331, 'BONAP', "Bon app'", 88.5)
# (10753, 'FRANS', 'Franchi S.p.A.', 88.0)
# (11067, 'DRACD', 'Drachenblut Delikatessen', 86.85)
# (10281, 'ROMEY', 'Romero y tomillo', 86.5)
# (10391, 'DRACD', 'Drachenblut Delikatessen', 86.4)
# (10288, 'REGGC', 'Reggiani Caseifici', 80.1)
# (11019, 'RANCH', 'Rancho grande', 76.0)
# (10955, 'FOLKO', 'Folk och fä HB', 74.4)
# (10371, 'LAMAI', "La maison d'Asie", 72.96)
# (10589, 'GREAL', 'Great Lakes Food Market', 72.0)
# (10887, 'GALED', 'Galería del gastrónomo', 70.0)
# (10992, 'THEBI', 'The Big Cheese', 69.6)
# (10683, 'DUMON', 'Du monde entier', 63.0)
# (11037, 'GODOS', 'Godos Cocina Típica', 60.0)
# (10963, 'FURIB', 'Furia Bacalhau e Frutos do Mar', 57.8)
# (10620, 'LAUGB', 'Laughing Bacchus Wine Cellars', 57.5)
# (10631, 'LAMAI', "La maison d'Asie", 55.8)
# (10754, 'MAGAA', 'Magazzini Alimentari Riuniti', 55.2)
# (10738, 'SPECD', 'Spécialités du monde', 52.35)
# (10422, 'FRANS', 'Franchi S.p.A.', 49.8)
# (10602, 'VAFFE', 'Vaffeljernet', 48.75)
# (10271, 'SPLIR', 'Split Rail Beer & Ale', 48.0)
# (10674, 'ISLAT', 'Island Trading', 45.0)
# (11057, 'NORTS', 'North/South', 45.0)
# (10815, 'SAVEA', 'Save-a-lot Markets', 40.0)
# (11051, 'LAMAI', "La maison d'Asie", 36.0)
# (10883, 'LONEP', 'Lonesome Pine Restaurant', 36.0)
# (10900, 'WELLI', 'Wellington Importadora', 33.75)
# (10898, 'OCEAN', 'Océano Atlántico Ltda.', 30.0)
# (10767, 'SUPRD', 'Suprêmes délices', 28.0)
# (10586, 'REGGC', 'Reggiani Caseifici', 23.8)
# (10807, 'FRANS', 'Franchi S.p.A.', 18.4)
# (10782, 'CACTU', 'Cactus Comidas para llevar', 12.5)

# %%
pg_cursor.close()
pg_conexion.close()

sql_cursor.close()
sql_conexion.close()
